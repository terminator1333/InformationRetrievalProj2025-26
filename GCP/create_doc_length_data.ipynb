# %%
from google.colab import auth
auth.authenticate_user()

project_id = 'eyalinforetrievalproject' #GCP Project ID
# !gcloud config set project {project_id}


# !gsutil cp gs://eyalir1/inverted_index_gcp.py . # downloading the inverted_index_gcp.py


# !mkdir -p postings_gcp_body # creating the directory locally


print("Downloading posting files")
# !gsutil -m cp -r gs://eyalir1/postings_gcp_body/* postings_gcp_body/ # downloading the index and all .bin files

print("Download complete.")
# Out:
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey
#
# Copying gs://eyalir1/inverted_index_gcp.py...
# / [1 files][  7.9 KiB/  7.9 KiB]
# Operation completed over 1 objects/7.9 KiB.
# Downloading posting files... this may take 2-3 minutes...
# Copying gs://eyalir1/postings_gcp_body/0_000.bin...
# Copying gs://eyalir1/postings_gcp_body/0_002.bin...
# Copying gs://eyalir1/postings_gcp_body/0_004.bin...
# Copying gs://eyalir1/postings_gcp_body/0_001.bin...
# Copying gs://eyalir1/postings_gcp_body/0_003.bin...
# Copying gs://eyalir1/postings_gcp_body/0_007.bin...
# Copying gs://eyalir1/postings_gcp_body/0_006.bin...
# Copying gs://eyalir1/postings_gcp_body/0_005.bin...
# Copying gs://eyalir1/postings_gcp_body/0_008.bin...
# Copying gs://eyalir1/postings_gcp_body/0_009.bin...
# Copying gs://eyalir1/postings_gcp_body/0_010.bin...
# Copying gs://eyalir1/postings_gcp_body/0_011.bin...
# Copying gs://eyalir1/postings_gcp_body/0_012.bin...
# Copying gs://eyalir1/postings_gcp_body/0_013.bin...
# Copying gs://eyalir1/postings_gcp_body/0_014.bin...
# Copying gs://eyalir1/postings_gcp_body/0_015.bin...
# Copying gs://eyalir1/postings_gcp_body/0_016.bin...
# Copying gs://eyalir1/postings_gcp_body/0_017.bin...
# Copying gs://eyalir1/postings_gcp_body/0_018.bin...
# Copying gs://eyalir1/postings_gcp_body/0_019.bin...
# Copying gs://eyalir1/postings_gcp_body/0_020.bin...
# Copying gs://eyalir1/postings_gcp_body/0_021.bin...
# Copying gs://eyalir1/postings_gcp_body/0_022.bin...
# Copying gs://eyalir1/postings_gcp_body/0_023.bin...
# Copying gs://eyalir1/postings_gcp_body/0_024.bin...
# Copying gs://eyalir1/postings_gcp_body/0_025.bin...
# Copying gs://eyalir1/postings_gcp_body/0_026.bin...
# Copying gs://eyalir1/postings_gcp_body/0_027.bin...
# Copying gs://eyalir1/postings_gcp_body/0_028.bin...
# Copying gs://eyalir1/postings_gcp_body/0_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/100_000.bin...
# Copying gs://eyalir1/postings_gcp_body/100_001.bin...
# Copying gs://eyalir1/postings_gcp_body/100_002.bin...
# Copying gs://eyalir1/postings_gcp_body/100_003.bin...
# Copying gs://eyalir1/postings_gcp_body/100_004.bin...
# Copying gs://eyalir1/postings_gcp_body/100_005.bin...
# Copying gs://eyalir1/postings_gcp_body/100_006.bin...
# Copying gs://eyalir1/postings_gcp_body/100_007.bin...
# Copying gs://eyalir1/postings_gcp_body/100_008.bin...
# Copying gs://eyalir1/postings_gcp_body/100_009.bin...
# Copying gs://eyalir1/postings_gcp_body/100_010.bin...
# Copying gs://eyalir1/postings_gcp_body/100_011.bin...
# Copying gs://eyalir1/postings_gcp_body/100_012.bin...
# Copying gs://eyalir1/postings_gcp_body/100_013.bin...
# Copying gs://eyalir1/postings_gcp_body/100_014.bin...
# Copying gs://eyalir1/postings_gcp_body/100_015.bin...
# Copying gs://eyalir1/postings_gcp_body/100_016.bin...
# Copying gs://eyalir1/postings_gcp_body/100_017.bin...
# Copying gs://eyalir1/postings_gcp_body/100_018.bin...
# Copying gs://eyalir1/postings_gcp_body/100_019.bin...
# Copying gs://eyalir1/postings_gcp_body/100_020.bin...
# Copying gs://eyalir1/postings_gcp_body/100_021.bin...
# Copying gs://eyalir1/postings_gcp_body/100_022.bin...
# Copying gs://eyalir1/postings_gcp_body/100_023.bin...
# Copying gs://eyalir1/postings_gcp_body/100_024.bin...
# Copying gs://eyalir1/postings_gcp_body/100_025.bin...
# Copying gs://eyalir1/postings_gcp_body/100_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/101_000.bin...
# Copying gs://eyalir1/postings_gcp_body/101_001.bin...
# Copying gs://eyalir1/postings_gcp_body/101_002.bin...
# Copying gs://eyalir1/postings_gcp_body/101_003.bin...
# Copying gs://eyalir1/postings_gcp_body/101_004.bin...
# Copying gs://eyalir1/postings_gcp_body/101_007.bin...
# Copying gs://eyalir1/postings_gcp_body/101_005.bin...
# Copying gs://eyalir1/postings_gcp_body/101_006.bin...
# Copying gs://eyalir1/postings_gcp_body/101_008.bin...
# Copying gs://eyalir1/postings_gcp_body/101_009.bin...
# Copying gs://eyalir1/postings_gcp_body/101_010.bin...
# Copying gs://eyalir1/postings_gcp_body/101_011.bin...
# Copying gs://eyalir1/postings_gcp_body/101_012.bin...
# Copying gs://eyalir1/postings_gcp_body/101_013.bin...
# Copying gs://eyalir1/postings_gcp_body/101_014.bin...
# Copying gs://eyalir1/postings_gcp_body/101_015.bin...
# Copying gs://eyalir1/postings_gcp_body/101_016.bin...
# Copying gs://eyalir1/postings_gcp_body/101_017.bin...
# Copying gs://eyalir1/postings_gcp_body/101_019.bin...
# Copying gs://eyalir1/postings_gcp_body/101_018.bin...
# Copying gs://eyalir1/postings_gcp_body/101_020.bin...
# Copying gs://eyalir1/postings_gcp_body/101_021.bin...
# Copying gs://eyalir1/postings_gcp_body/101_022.bin...
# Copying gs://eyalir1/postings_gcp_body/101_023.bin...
# Copying gs://eyalir1/postings_gcp_body/101_024.bin...
# Copying gs://eyalir1/postings_gcp_body/101_025.bin...
# Copying gs://eyalir1/postings_gcp_body/101_026.bin...
# Copying gs://eyalir1/postings_gcp_body/101_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/102_000.bin...
# Copying gs://eyalir1/postings_gcp_body/102_001.bin...
# Copying gs://eyalir1/postings_gcp_body/102_002.bin...
# Copying gs://eyalir1/postings_gcp_body/102_003.bin...
# Copying gs://eyalir1/postings_gcp_body/102_004.bin...
# Copying gs://eyalir1/postings_gcp_body/102_005.bin...
# Copying gs://eyalir1/postings_gcp_body/102_006.bin...
# Copying gs://eyalir1/postings_gcp_body/102_007.bin...
# Copying gs://eyalir1/postings_gcp_body/102_008.bin...
# Copying gs://eyalir1/postings_gcp_body/102_009.bin...
# Copying gs://eyalir1/postings_gcp_body/102_010.bin...
# Copying gs://eyalir1/postings_gcp_body/102_011.bin...
# Copying gs://eyalir1/postings_gcp_body/102_012.bin...
# Copying gs://eyalir1/postings_gcp_body/102_014.bin...
# Copying gs://eyalir1/postings_gcp_body/102_013.bin...
# Copying gs://eyalir1/postings_gcp_body/102_015.bin...
# Copying gs://eyalir1/postings_gcp_body/102_016.bin...
# Copying gs://eyalir1/postings_gcp_body/102_017.bin...
# Copying gs://eyalir1/postings_gcp_body/102_018.bin...
# Copying gs://eyalir1/postings_gcp_body/102_019.bin...
# Copying gs://eyalir1/postings_gcp_body/102_020.bin...
# Copying gs://eyalir1/postings_gcp_body/102_021.bin...
# Copying gs://eyalir1/postings_gcp_body/102_022.bin...
# Copying gs://eyalir1/postings_gcp_body/102_023.bin...
# Copying gs://eyalir1/postings_gcp_body/102_024.bin...
# Copying gs://eyalir1/postings_gcp_body/102_025.bin...
# Copying gs://eyalir1/postings_gcp_body/102_026.bin...
# Copying gs://eyalir1/postings_gcp_body/102_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/103_000.bin...
# Copying gs://eyalir1/postings_gcp_body/103_001.bin...
# Copying gs://eyalir1/postings_gcp_body/103_002.bin...
# Copying gs://eyalir1/postings_gcp_body/103_003.bin...
# Copying gs://eyalir1/postings_gcp_body/103_005.bin...
# Copying gs://eyalir1/postings_gcp_body/103_004.bin...
# Copying gs://eyalir1/postings_gcp_body/103_006.bin...
# Copying gs://eyalir1/postings_gcp_body/103_007.bin...
# Copying gs://eyalir1/postings_gcp_body/103_008.bin...
# Copying gs://eyalir1/postings_gcp_body/103_009.bin...
# Copying gs://eyalir1/postings_gcp_body/103_010.bin...
# Copying gs://eyalir1/postings_gcp_body/103_011.bin...
# Copying gs://eyalir1/postings_gcp_body/103_012.bin...
# Copying gs://eyalir1/postings_gcp_body/103_014.bin...
# Copying gs://eyalir1/postings_gcp_body/103_013.bin...
# Copying gs://eyalir1/postings_gcp_body/103_015.bin...
# Copying gs://eyalir1/postings_gcp_body/103_016.bin...
# Copying gs://eyalir1/postings_gcp_body/103_017.bin...
# Copying gs://eyalir1/postings_gcp_body/103_018.bin...
# Copying gs://eyalir1/postings_gcp_body/103_019.bin...
# Copying gs://eyalir1/postings_gcp_body/103_020.bin...
# Copying gs://eyalir1/postings_gcp_body/103_021.bin...
# Copying gs://eyalir1/postings_gcp_body/103_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/104_000.bin...
# Copying gs://eyalir1/postings_gcp_body/104_001.bin...
# Copying gs://eyalir1/postings_gcp_body/104_002.bin...
# Copying gs://eyalir1/postings_gcp_body/104_003.bin...
# Copying gs://eyalir1/postings_gcp_body/104_004.bin...
# Copying gs://eyalir1/postings_gcp_body/104_005.bin...
# Copying gs://eyalir1/postings_gcp_body/104_006.bin...
# Copying gs://eyalir1/postings_gcp_body/104_007.bin...
# Copying gs://eyalir1/postings_gcp_body/104_008.bin...
# Copying gs://eyalir1/postings_gcp_body/104_009.bin...
# Copying gs://eyalir1/postings_gcp_body/104_010.bin...
# Copying gs://eyalir1/postings_gcp_body/104_011.bin...
# Copying gs://eyalir1/postings_gcp_body/104_012.bin...
# Copying gs://eyalir1/postings_gcp_body/104_013.bin...
# Copying gs://eyalir1/postings_gcp_body/104_014.bin...
# Copying gs://eyalir1/postings_gcp_body/104_015.bin...
# Copying gs://eyalir1/postings_gcp_body/104_016.bin...
# Copying gs://eyalir1/postings_gcp_body/104_017.bin...
# Copying gs://eyalir1/postings_gcp_body/104_018.bin...
# Copying gs://eyalir1/postings_gcp_body/104_019.bin...
# Copying gs://eyalir1/postings_gcp_body/104_020.bin...
# Copying gs://eyalir1/postings_gcp_body/104_021.bin...
# Copying gs://eyalir1/postings_gcp_body/104_022.bin...
# Copying gs://eyalir1/postings_gcp_body/104_023.bin...
# Copying gs://eyalir1/postings_gcp_body/104_024.bin...
# Copying gs://eyalir1/postings_gcp_body/104_025.bin...
# Copying gs://eyalir1/postings_gcp_body/104_026.bin...
# Copying gs://eyalir1/postings_gcp_body/104_027.bin...
# Copying gs://eyalir1/postings_gcp_body/104_028.bin...
# Copying gs://eyalir1/postings_gcp_body/104_029.bin...
# Copying gs://eyalir1/postings_gcp_body/104_030.bin...
# Copying gs://eyalir1/postings_gcp_body/104_031.bin...
# Copying gs://eyalir1/postings_gcp_body/104_032.bin...
# Copying gs://eyalir1/postings_gcp_body/104_033.bin...
# Copying gs://eyalir1/postings_gcp_body/104_034.bin...
# Copying gs://eyalir1/postings_gcp_body/104_035.bin...
# Copying gs://eyalir1/postings_gcp_body/104_036.bin...
# Copying gs://eyalir1/postings_gcp_body/105_000.bin...
# Copying gs://eyalir1/postings_gcp_body/104_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/105_001.bin...
# Copying gs://eyalir1/postings_gcp_body/105_002.bin...
# Copying gs://eyalir1/postings_gcp_body/105_003.bin...
# Copying gs://eyalir1/postings_gcp_body/105_004.bin...
# Copying gs://eyalir1/postings_gcp_body/105_005.bin...
# Copying gs://eyalir1/postings_gcp_body/105_006.bin...
# Copying gs://eyalir1/postings_gcp_body/105_007.bin...
# Copying gs://eyalir1/postings_gcp_body/105_008.bin...
# Copying gs://eyalir1/postings_gcp_body/105_009.bin...
# Copying gs://eyalir1/postings_gcp_body/105_010.bin...
# Copying gs://eyalir1/postings_gcp_body/105_011.bin...
# Copying gs://eyalir1/postings_gcp_body/105_012.bin...
# Copying gs://eyalir1/postings_gcp_body/105_013.bin...
# Copying gs://eyalir1/postings_gcp_body/105_014.bin...
# Copying gs://eyalir1/postings_gcp_body/105_015.bin...
# Copying gs://eyalir1/postings_gcp_body/105_016.bin...
# Copying gs://eyalir1/postings_gcp_body/105_017.bin...
# Copying gs://eyalir1/postings_gcp_body/105_018.bin...
# Copying gs://eyalir1/postings_gcp_body/105_019.bin...
# Copying gs://eyalir1/postings_gcp_body/105_020.bin...
# Copying gs://eyalir1/postings_gcp_body/105_021.bin...
# Copying gs://eyalir1/postings_gcp_body/105_022.bin...
# Copying gs://eyalir1/postings_gcp_body/105_023.bin...
# Copying gs://eyalir1/postings_gcp_body/105_024.bin...
# Copying gs://eyalir1/postings_gcp_body/105_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/106_000.bin...
# Copying gs://eyalir1/postings_gcp_body/106_001.bin...
# Copying gs://eyalir1/postings_gcp_body/106_002.bin...
# Copying gs://eyalir1/postings_gcp_body/106_003.bin...
# Copying gs://eyalir1/postings_gcp_body/106_004.bin...
# Copying gs://eyalir1/postings_gcp_body/106_005.bin...
# Copying gs://eyalir1/postings_gcp_body/106_006.bin...
# Copying gs://eyalir1/postings_gcp_body/106_007.bin...
# Copying gs://eyalir1/postings_gcp_body/106_008.bin...
# Copying gs://eyalir1/postings_gcp_body/106_009.bin...
# Copying gs://eyalir1/postings_gcp_body/106_010.bin...
# Copying gs://eyalir1/postings_gcp_body/106_011.bin...
# Copying gs://eyalir1/postings_gcp_body/106_012.bin...
# Copying gs://eyalir1/postings_gcp_body/106_013.bin...
# Copying gs://eyalir1/postings_gcp_body/106_014.bin...
# Copying gs://eyalir1/postings_gcp_body/106_015.bin...
# Copying gs://eyalir1/postings_gcp_body/106_016.bin...
# Copying gs://eyalir1/postings_gcp_body/106_017.bin...
# Copying gs://eyalir1/postings_gcp_body/106_018.bin...
# Copying gs://eyalir1/postings_gcp_body/106_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/107_000.bin...
# Copying gs://eyalir1/postings_gcp_body/107_001.bin...
# Copying gs://eyalir1/postings_gcp_body/107_002.bin...
# Copying gs://eyalir1/postings_gcp_body/107_003.bin...
# Copying gs://eyalir1/postings_gcp_body/107_004.bin...
# Copying gs://eyalir1/postings_gcp_body/107_005.bin...
# Copying gs://eyalir1/postings_gcp_body/107_006.bin...
# Copying gs://eyalir1/postings_gcp_body/107_007.bin...
# Copying gs://eyalir1/postings_gcp_body/107_008.bin...
# Copying gs://eyalir1/postings_gcp_body/107_009.bin...
# Copying gs://eyalir1/postings_gcp_body/107_011.bin...
# Copying gs://eyalir1/postings_gcp_body/107_010.bin...
# Copying gs://eyalir1/postings_gcp_body/107_012.bin...
# Copying gs://eyalir1/postings_gcp_body/107_013.bin...
# Copying gs://eyalir1/postings_gcp_body/107_014.bin...
# Copying gs://eyalir1/postings_gcp_body/107_015.bin...
# Copying gs://eyalir1/postings_gcp_body/107_016.bin...
# Copying gs://eyalir1/postings_gcp_body/107_017.bin...
# Copying gs://eyalir1/postings_gcp_body/107_018.bin...
# Copying gs://eyalir1/postings_gcp_body/107_019.bin...
# Copying gs://eyalir1/postings_gcp_body/107_020.bin...
# Copying gs://eyalir1/postings_gcp_body/107_021.bin...
# Copying gs://eyalir1/postings_gcp_body/107_023.bin...
# Copying gs://eyalir1/postings_gcp_body/107_022.bin...
# Copying gs://eyalir1/postings_gcp_body/107_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/108_000.bin...
# Copying gs://eyalir1/postings_gcp_body/108_001.bin...
# Copying gs://eyalir1/postings_gcp_body/108_002.bin...
# Copying gs://eyalir1/postings_gcp_body/108_003.bin...
# Copying gs://eyalir1/postings_gcp_body/108_004.bin...
# Copying gs://eyalir1/postings_gcp_body/108_005.bin...
# Copying gs://eyalir1/postings_gcp_body/108_006.bin...
# Copying gs://eyalir1/postings_gcp_body/108_009.bin...
# Copying gs://eyalir1/postings_gcp_body/108_007.bin...
# Copying gs://eyalir1/postings_gcp_body/108_008.bin...
# Copying gs://eyalir1/postings_gcp_body/108_010.bin...
# Copying gs://eyalir1/postings_gcp_body/108_011.bin...
# Copying gs://eyalir1/postings_gcp_body/108_012.bin...
# Copying gs://eyalir1/postings_gcp_body/108_013.bin...
# Copying gs://eyalir1/postings_gcp_body/108_014.bin...
# Copying gs://eyalir1/postings_gcp_body/108_015.bin...
# Copying gs://eyalir1/postings_gcp_body/108_016.bin...
# Copying gs://eyalir1/postings_gcp_body/108_018.bin...
# Copying gs://eyalir1/postings_gcp_body/108_017.bin...
# Copying gs://eyalir1/postings_gcp_body/108_019.bin...
# Copying gs://eyalir1/postings_gcp_body/108_020.bin...
# Copying gs://eyalir1/postings_gcp_body/108_021.bin...
# Copying gs://eyalir1/postings_gcp_body/108_022.bin...
# Copying gs://eyalir1/postings_gcp_body/109_000.bin...
# Copying gs://eyalir1/postings_gcp_body/108_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/109_001.bin...
# Copying gs://eyalir1/postings_gcp_body/109_002.bin...
# Copying gs://eyalir1/postings_gcp_body/109_003.bin...
# Copying gs://eyalir1/postings_gcp_body/109_004.bin...
# Copying gs://eyalir1/postings_gcp_body/109_005.bin...
# Copying gs://eyalir1/postings_gcp_body/109_006.bin...
# Copying gs://eyalir1/postings_gcp_body/109_008.bin...
# Copying gs://eyalir1/postings_gcp_body/109_007.bin...
# Copying gs://eyalir1/postings_gcp_body/109_009.bin...
# Copying gs://eyalir1/postings_gcp_body/109_010.bin...
# Copying gs://eyalir1/postings_gcp_body/109_011.bin...
# Copying gs://eyalir1/postings_gcp_body/109_012.bin...
# Copying gs://eyalir1/postings_gcp_body/109_013.bin...
# Copying gs://eyalir1/postings_gcp_body/109_014.bin...
# Copying gs://eyalir1/postings_gcp_body/109_015.bin...
# Copying gs://eyalir1/postings_gcp_body/109_016.bin...
# Copying gs://eyalir1/postings_gcp_body/109_017.bin...
# Copying gs://eyalir1/postings_gcp_body/109_019.bin...
# Copying gs://eyalir1/postings_gcp_body/109_018.bin...
# Copying gs://eyalir1/postings_gcp_body/109_020.bin...
# Copying gs://eyalir1/postings_gcp_body/109_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/10_000.bin...
# Copying gs://eyalir1/postings_gcp_body/10_001.bin...
# Copying gs://eyalir1/postings_gcp_body/10_002.bin...
# Copying gs://eyalir1/postings_gcp_body/10_003.bin...
# Copying gs://eyalir1/postings_gcp_body/10_004.bin...
# Copying gs://eyalir1/postings_gcp_body/10_005.bin...
# Copying gs://eyalir1/postings_gcp_body/10_006.bin...
# Copying gs://eyalir1/postings_gcp_body/10_007.bin...
# Copying gs://eyalir1/postings_gcp_body/10_008.bin...
# Copying gs://eyalir1/postings_gcp_body/10_009.bin...
# Copying gs://eyalir1/postings_gcp_body/10_010.bin...
# Copying gs://eyalir1/postings_gcp_body/10_011.bin...
# Copying gs://eyalir1/postings_gcp_body/10_012.bin...
# Copying gs://eyalir1/postings_gcp_body/10_013.bin...
# Copying gs://eyalir1/postings_gcp_body/10_014.bin...
# Copying gs://eyalir1/postings_gcp_body/10_015.bin...
# Copying gs://eyalir1/postings_gcp_body/10_016.bin...
# Copying gs://eyalir1/postings_gcp_body/10_017.bin...
# Copying gs://eyalir1/postings_gcp_body/10_018.bin...
# Copying gs://eyalir1/postings_gcp_body/10_019.bin...
# Copying gs://eyalir1/postings_gcp_body/10_020.bin...
# Copying gs://eyalir1/postings_gcp_body/10_021.bin...
# Copying gs://eyalir1/postings_gcp_body/10_022.bin...
# Copying gs://eyalir1/postings_gcp_body/10_023.bin...
# Copying gs://eyalir1/postings_gcp_body/10_024.bin...
# Copying gs://eyalir1/postings_gcp_body/10_025.bin...
# Copying gs://eyalir1/postings_gcp_body/10_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/110_000.bin...
# Copying gs://eyalir1/postings_gcp_body/110_001.bin...
# Copying gs://eyalir1/postings_gcp_body/110_002.bin...
# Copying gs://eyalir1/postings_gcp_body/110_003.bin...
# Copying gs://eyalir1/postings_gcp_body/110_004.bin...
# Copying gs://eyalir1/postings_gcp_body/110_005.bin...
# Copying gs://eyalir1/postings_gcp_body/110_006.bin...
# Copying gs://eyalir1/postings_gcp_body/110_007.bin...
# Copying gs://eyalir1/postings_gcp_body/110_008.bin...
# Copying gs://eyalir1/postings_gcp_body/110_009.bin...
# Copying gs://eyalir1/postings_gcp_body/110_010.bin...
# Copying gs://eyalir1/postings_gcp_body/110_011.bin...
# Copying gs://eyalir1/postings_gcp_body/110_012.bin...
# Copying gs://eyalir1/postings_gcp_body/110_013.bin...
# Copying gs://eyalir1/postings_gcp_body/110_015.bin...
# Copying gs://eyalir1/postings_gcp_body/110_014.bin...
# Copying gs://eyalir1/postings_gcp_body/110_016.bin...
# Copying gs://eyalir1/postings_gcp_body/110_018.bin...
# Copying gs://eyalir1/postings_gcp_body/110_017.bin...
# Copying gs://eyalir1/postings_gcp_body/110_019.bin...
# Copying gs://eyalir1/postings_gcp_body/110_020.bin...
# Copying gs://eyalir1/postings_gcp_body/110_021.bin...
# Copying gs://eyalir1/postings_gcp_body/110_022.bin...
# Copying gs://eyalir1/postings_gcp_body/110_023.bin...
# Copying gs://eyalir1/postings_gcp_body/110_024.bin...
# Copying gs://eyalir1/postings_gcp_body/110_025.bin...
# Copying gs://eyalir1/postings_gcp_body/110_026.bin...
# Copying gs://eyalir1/postings_gcp_body/110_027.bin...
# Copying gs://eyalir1/postings_gcp_body/110_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/111_000.bin...
# Copying gs://eyalir1/postings_gcp_body/111_001.bin...
# Copying gs://eyalir1/postings_gcp_body/111_002.bin...
# Copying gs://eyalir1/postings_gcp_body/111_003.bin...
# Copying gs://eyalir1/postings_gcp_body/111_004.bin...
# Copying gs://eyalir1/postings_gcp_body/111_005.bin...
# Copying gs://eyalir1/postings_gcp_body/111_006.bin...
# Copying gs://eyalir1/postings_gcp_body/111_007.bin...
# Copying gs://eyalir1/postings_gcp_body/111_008.bin...
# Copying gs://eyalir1/postings_gcp_body/111_009.bin...
# Copying gs://eyalir1/postings_gcp_body/111_010.bin...
# Copying gs://eyalir1/postings_gcp_body/111_011.bin...
# Copying gs://eyalir1/postings_gcp_body/111_013.bin...
# Copying gs://eyalir1/postings_gcp_body/111_012.bin...
# Copying gs://eyalir1/postings_gcp_body/111_014.bin...
# Copying gs://eyalir1/postings_gcp_body/111_015.bin...
# Copying gs://eyalir1/postings_gcp_body/111_016.bin...
# Copying gs://eyalir1/postings_gcp_body/111_017.bin...
# Copying gs://eyalir1/postings_gcp_body/111_018.bin...
# Copying gs://eyalir1/postings_gcp_body/111_019.bin...
# Copying gs://eyalir1/postings_gcp_body/111_020.bin...
# Copying gs://eyalir1/postings_gcp_body/111_021.bin...
# Copying gs://eyalir1/postings_gcp_body/111_022.bin...
# Copying gs://eyalir1/postings_gcp_body/111_023.bin...
# Copying gs://eyalir1/postings_gcp_body/111_024.bin...
# Copying gs://eyalir1/postings_gcp_body/111_025.bin...
# Copying gs://eyalir1/postings_gcp_body/111_026.bin...
# Copying gs://eyalir1/postings_gcp_body/111_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/112_000.bin...
# Copying gs://eyalir1/postings_gcp_body/112_001.bin...
# Copying gs://eyalir1/postings_gcp_body/112_002.bin...
# Copying gs://eyalir1/postings_gcp_body/112_003.bin...
# Copying gs://eyalir1/postings_gcp_body/112_004.bin...
# Copying gs://eyalir1/postings_gcp_body/112_005.bin...
# Copying gs://eyalir1/postings_gcp_body/112_006.bin...
# Copying gs://eyalir1/postings_gcp_body/112_007.bin...
# Copying gs://eyalir1/postings_gcp_body/112_008.bin...
# Copying gs://eyalir1/postings_gcp_body/112_009.bin...
# Copying gs://eyalir1/postings_gcp_body/112_010.bin...
# Copying gs://eyalir1/postings_gcp_body/112_012.bin...
# Copying gs://eyalir1/postings_gcp_body/112_011.bin...
# Copying gs://eyalir1/postings_gcp_body/112_013.bin...
# Copying gs://eyalir1/postings_gcp_body/112_014.bin...
# Copying gs://eyalir1/postings_gcp_body/112_015.bin...
# Copying gs://eyalir1/postings_gcp_body/112_016.bin...
# Copying gs://eyalir1/postings_gcp_body/112_017.bin...
# Copying gs://eyalir1/postings_gcp_body/112_018.bin...
# Copying gs://eyalir1/postings_gcp_body/112_019.bin...
# Copying gs://eyalir1/postings_gcp_body/112_020.bin...
# Copying gs://eyalir1/postings_gcp_body/112_021.bin...
# Copying gs://eyalir1/postings_gcp_body/112_022.bin...
# Copying gs://eyalir1/postings_gcp_body/112_023.bin...
# Copying gs://eyalir1/postings_gcp_body/112_024.bin...
# Copying gs://eyalir1/postings_gcp_body/112_025.bin...
# Copying gs://eyalir1/postings_gcp_body/112_026.bin...
# Copying gs://eyalir1/postings_gcp_body/112_027.bin...
# Copying gs://eyalir1/postings_gcp_body/112_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/113_000.bin...
# Copying gs://eyalir1/postings_gcp_body/113_001.bin...
# Copying gs://eyalir1/postings_gcp_body/113_002.bin...
# Copying gs://eyalir1/postings_gcp_body/113_003.bin...
# Copying gs://eyalir1/postings_gcp_body/113_004.bin...
# Copying gs://eyalir1/postings_gcp_body/113_005.bin...
# Copying gs://eyalir1/postings_gcp_body/113_006.bin...
# Copying gs://eyalir1/postings_gcp_body/113_007.bin...
# Copying gs://eyalir1/postings_gcp_body/113_008.bin...
# Copying gs://eyalir1/postings_gcp_body/113_009.bin...
# Copying gs://eyalir1/postings_gcp_body/113_010.bin...
# Copying gs://eyalir1/postings_gcp_body/113_011.bin...
# Copying gs://eyalir1/postings_gcp_body/113_012.bin...
# Copying gs://eyalir1/postings_gcp_body/113_013.bin...
# Copying gs://eyalir1/postings_gcp_body/113_014.bin...
# Copying gs://eyalir1/postings_gcp_body/113_015.bin...
# Copying gs://eyalir1/postings_gcp_body/113_016.bin...
# Copying gs://eyalir1/postings_gcp_body/113_017.bin...
# Copying gs://eyalir1/postings_gcp_body/113_018.bin...
# Copying gs://eyalir1/postings_gcp_body/113_019.bin...
# Copying gs://eyalir1/postings_gcp_body/113_020.bin...
# Copying gs://eyalir1/postings_gcp_body/113_021.bin...
# Copying gs://eyalir1/postings_gcp_body/113_022.bin...
# Copying gs://eyalir1/postings_gcp_body/113_023.bin...
# Copying gs://eyalir1/postings_gcp_body/113_024.bin...
# Copying gs://eyalir1/postings_gcp_body/113_025.bin...
# Copying gs://eyalir1/postings_gcp_body/113_026.bin...
# Copying gs://eyalir1/postings_gcp_body/113_027.bin...
# Copying gs://eyalir1/postings_gcp_body/113_028.bin...
# Copying gs://eyalir1/postings_gcp_body/113_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/114_000.bin...
# Copying gs://eyalir1/postings_gcp_body/114_001.bin...
# Copying gs://eyalir1/postings_gcp_body/114_002.bin...
# Copying gs://eyalir1/postings_gcp_body/114_003.bin...
# Copying gs://eyalir1/postings_gcp_body/114_004.bin...
# Copying gs://eyalir1/postings_gcp_body/114_005.bin...
# Copying gs://eyalir1/postings_gcp_body/114_006.bin...
# Copying gs://eyalir1/postings_gcp_body/114_009.bin...
# Copying gs://eyalir1/postings_gcp_body/114_007.bin...
# Copying gs://eyalir1/postings_gcp_body/114_010.bin...
# Copying gs://eyalir1/postings_gcp_body/114_011.bin...
# Copying gs://eyalir1/postings_gcp_body/114_008.bin...
# Copying gs://eyalir1/postings_gcp_body/114_012.bin...
# Copying gs://eyalir1/postings_gcp_body/114_013.bin...
# Copying gs://eyalir1/postings_gcp_body/114_014.bin...
# Copying gs://eyalir1/postings_gcp_body/114_015.bin...
# Copying gs://eyalir1/postings_gcp_body/114_016.bin...
# Copying gs://eyalir1/postings_gcp_body/114_017.bin...
# Copying gs://eyalir1/postings_gcp_body/114_018.bin...
# Copying gs://eyalir1/postings_gcp_body/114_019.bin...
# Copying gs://eyalir1/postings_gcp_body/114_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/115_000.bin...
# Copying gs://eyalir1/postings_gcp_body/115_001.bin...
# Copying gs://eyalir1/postings_gcp_body/115_003.bin...
# Copying gs://eyalir1/postings_gcp_body/115_002.bin...
# Copying gs://eyalir1/postings_gcp_body/115_004.bin...
# Copying gs://eyalir1/postings_gcp_body/115_005.bin...
# Copying gs://eyalir1/postings_gcp_body/115_006.bin...
# Copying gs://eyalir1/postings_gcp_body/115_007.bin...
# Copying gs://eyalir1/postings_gcp_body/115_008.bin...
# Copying gs://eyalir1/postings_gcp_body/115_009.bin...
# Copying gs://eyalir1/postings_gcp_body/115_010.bin...
# Copying gs://eyalir1/postings_gcp_body/115_011.bin...
# Copying gs://eyalir1/postings_gcp_body/115_012.bin...
# Copying gs://eyalir1/postings_gcp_body/115_013.bin...
# Copying gs://eyalir1/postings_gcp_body/115_014.bin...
# Copying gs://eyalir1/postings_gcp_body/115_015.bin...
# Copying gs://eyalir1/postings_gcp_body/115_016.bin...
# Copying gs://eyalir1/postings_gcp_body/115_017.bin...
# Copying gs://eyalir1/postings_gcp_body/115_018.bin...
# Copying gs://eyalir1/postings_gcp_body/115_019.bin...
# Copying gs://eyalir1/postings_gcp_body/115_020.bin...
# Copying gs://eyalir1/postings_gcp_body/115_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/116_000.bin...
# Copying gs://eyalir1/postings_gcp_body/116_001.bin...
# Copying gs://eyalir1/postings_gcp_body/116_002.bin...
# Copying gs://eyalir1/postings_gcp_body/116_003.bin...
# Copying gs://eyalir1/postings_gcp_body/116_004.bin...
# Copying gs://eyalir1/postings_gcp_body/116_005.bin...
# Copying gs://eyalir1/postings_gcp_body/116_006.bin...
# Copying gs://eyalir1/postings_gcp_body/116_007.bin...
# Copying gs://eyalir1/postings_gcp_body/116_008.bin...
# Copying gs://eyalir1/postings_gcp_body/116_009.bin...
# Copying gs://eyalir1/postings_gcp_body/116_010.bin...
# Copying gs://eyalir1/postings_gcp_body/116_011.bin...
# Copying gs://eyalir1/postings_gcp_body/116_013.bin...
# Copying gs://eyalir1/postings_gcp_body/116_012.bin...
# Copying gs://eyalir1/postings_gcp_body/116_014.bin...
# Copying gs://eyalir1/postings_gcp_body/116_015.bin...
# Copying gs://eyalir1/postings_gcp_body/116_016.bin...
# Copying gs://eyalir1/postings_gcp_body/116_017.bin...
# Copying gs://eyalir1/postings_gcp_body/116_018.bin...
# Copying gs://eyalir1/postings_gcp_body/116_019.bin...
# Copying gs://eyalir1/postings_gcp_body/116_020.bin...
# Copying gs://eyalir1/postings_gcp_body/116_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/117_001.bin...
# Copying gs://eyalir1/postings_gcp_body/117_000.bin...
# Copying gs://eyalir1/postings_gcp_body/117_002.bin...
# Copying gs://eyalir1/postings_gcp_body/117_003.bin...
# Copying gs://eyalir1/postings_gcp_body/117_005.bin...
# Copying gs://eyalir1/postings_gcp_body/117_004.bin...
# Copying gs://eyalir1/postings_gcp_body/117_006.bin...
# Copying gs://eyalir1/postings_gcp_body/117_007.bin...
# Copying gs://eyalir1/postings_gcp_body/117_008.bin...
# Copying gs://eyalir1/postings_gcp_body/117_009.bin...
# Copying gs://eyalir1/postings_gcp_body/117_010.bin...
# Copying gs://eyalir1/postings_gcp_body/117_011.bin...
# Copying gs://eyalir1/postings_gcp_body/117_012.bin...
# Copying gs://eyalir1/postings_gcp_body/117_014.bin...
# Copying gs://eyalir1/postings_gcp_body/117_013.bin...
# Copying gs://eyalir1/postings_gcp_body/117_015.bin...
# Copying gs://eyalir1/postings_gcp_body/117_016.bin...
# Copying gs://eyalir1/postings_gcp_body/117_017.bin...
# Copying gs://eyalir1/postings_gcp_body/117_018.bin...
# Copying gs://eyalir1/postings_gcp_body/117_019.bin...
# Copying gs://eyalir1/postings_gcp_body/117_020.bin...
# Copying gs://eyalir1/postings_gcp_body/117_021.bin...
# Copying gs://eyalir1/postings_gcp_body/117_022.bin...
# Copying gs://eyalir1/postings_gcp_body/117_023.bin...
# Copying gs://eyalir1/postings_gcp_body/117_024.bin...
# Copying gs://eyalir1/postings_gcp_body/117_025.bin...
# Copying gs://eyalir1/postings_gcp_body/117_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/118_000.bin...
# Copying gs://eyalir1/postings_gcp_body/118_001.bin...
# Copying gs://eyalir1/postings_gcp_body/118_002.bin...
# Copying gs://eyalir1/postings_gcp_body/118_003.bin...
# Copying gs://eyalir1/postings_gcp_body/118_004.bin...
# Copying gs://eyalir1/postings_gcp_body/118_005.bin...
# Copying gs://eyalir1/postings_gcp_body/118_006.bin...
# Copying gs://eyalir1/postings_gcp_body/118_007.bin...
# Copying gs://eyalir1/postings_gcp_body/118_008.bin...
# Copying gs://eyalir1/postings_gcp_body/118_009.bin...
# Copying gs://eyalir1/postings_gcp_body/118_010.bin...
# Copying gs://eyalir1/postings_gcp_body/118_011.bin...
# Copying gs://eyalir1/postings_gcp_body/118_012.bin...
# Copying gs://eyalir1/postings_gcp_body/118_013.bin...
# Copying gs://eyalir1/postings_gcp_body/118_014.bin...
# Copying gs://eyalir1/postings_gcp_body/118_015.bin...
# Copying gs://eyalir1/postings_gcp_body/118_016.bin...
# Copying gs://eyalir1/postings_gcp_body/118_017.bin...
# Copying gs://eyalir1/postings_gcp_body/118_019.bin...
# Copying gs://eyalir1/postings_gcp_body/118_018.bin...
# Copying gs://eyalir1/postings_gcp_body/118_021.bin...
# Copying gs://eyalir1/postings_gcp_body/118_022.bin...
# Copying gs://eyalir1/postings_gcp_body/118_020.bin...
# Copying gs://eyalir1/postings_gcp_body/118_023.bin...
# Copying gs://eyalir1/postings_gcp_body/118_024.bin...
# Copying gs://eyalir1/postings_gcp_body/118_025.bin...
# Copying gs://eyalir1/postings_gcp_body/118_026.bin...
# Copying gs://eyalir1/postings_gcp_body/118_028.bin...
# Copying gs://eyalir1/postings_gcp_body/118_027.bin...
# Copying gs://eyalir1/postings_gcp_body/118_029.bin...
# Copying gs://eyalir1/postings_gcp_body/118_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/119_001.bin...
# Copying gs://eyalir1/postings_gcp_body/119_002.bin...
# Copying gs://eyalir1/postings_gcp_body/119_003.bin...
# Copying gs://eyalir1/postings_gcp_body/119_000.bin...
# Copying gs://eyalir1/postings_gcp_body/119_004.bin...
# Copying gs://eyalir1/postings_gcp_body/119_005.bin...
# Copying gs://eyalir1/postings_gcp_body/119_006.bin...
# Copying gs://eyalir1/postings_gcp_body/119_007.bin...
# Copying gs://eyalir1/postings_gcp_body/119_008.bin...
# Copying gs://eyalir1/postings_gcp_body/119_009.bin...
# Copying gs://eyalir1/postings_gcp_body/119_010.bin...
# Copying gs://eyalir1/postings_gcp_body/119_011.bin...
# Copying gs://eyalir1/postings_gcp_body/119_012.bin...
# Copying gs://eyalir1/postings_gcp_body/119_013.bin...
# Copying gs://eyalir1/postings_gcp_body/119_014.bin...
# Copying gs://eyalir1/postings_gcp_body/119_015.bin...
# Copying gs://eyalir1/postings_gcp_body/119_016.bin...
# Copying gs://eyalir1/postings_gcp_body/119_017.bin...
# Copying gs://eyalir1/postings_gcp_body/119_018.bin...
# Copying gs://eyalir1/postings_gcp_body/119_019.bin...
# Copying gs://eyalir1/postings_gcp_body/119_020.bin...
# Copying gs://eyalir1/postings_gcp_body/119_021.bin...
# Copying gs://eyalir1/postings_gcp_body/119_022.bin...
# Copying gs://eyalir1/postings_gcp_body/119_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/11_000.bin...
# Copying gs://eyalir1/postings_gcp_body/11_001.bin...
# Copying gs://eyalir1/postings_gcp_body/11_002.bin...
# Copying gs://eyalir1/postings_gcp_body/11_003.bin...
# Copying gs://eyalir1/postings_gcp_body/11_005.bin...
# Copying gs://eyalir1/postings_gcp_body/11_006.bin...
# Copying gs://eyalir1/postings_gcp_body/11_004.bin...
# Copying gs://eyalir1/postings_gcp_body/11_007.bin...
# Copying gs://eyalir1/postings_gcp_body/11_009.bin...
# Copying gs://eyalir1/postings_gcp_body/11_008.bin...
# Copying gs://eyalir1/postings_gcp_body/11_010.bin...
# Copying gs://eyalir1/postings_gcp_body/11_011.bin...
# Copying gs://eyalir1/postings_gcp_body/11_012.bin...
# Copying gs://eyalir1/postings_gcp_body/11_013.bin...
# Copying gs://eyalir1/postings_gcp_body/11_014.bin...
# Copying gs://eyalir1/postings_gcp_body/11_015.bin...
# Copying gs://eyalir1/postings_gcp_body/11_016.bin...
# Copying gs://eyalir1/postings_gcp_body/11_017.bin...
# Copying gs://eyalir1/postings_gcp_body/11_018.bin...
# Copying gs://eyalir1/postings_gcp_body/11_019.bin...
# Copying gs://eyalir1/postings_gcp_body/11_020.bin...
# Copying gs://eyalir1/postings_gcp_body/11_021.bin...
# Copying gs://eyalir1/postings_gcp_body/11_022.bin...
# Copying gs://eyalir1/postings_gcp_body/11_023.bin...
# Copying gs://eyalir1/postings_gcp_body/11_024.bin...
# Copying gs://eyalir1/postings_gcp_body/11_025.bin...
# Copying gs://eyalir1/postings_gcp_body/11_026.bin...
# Copying gs://eyalir1/postings_gcp_body/11_027.bin...
# Copying gs://eyalir1/postings_gcp_body/11_028.bin...
# Copying gs://eyalir1/postings_gcp_body/11_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/120_000.bin...
# Copying gs://eyalir1/postings_gcp_body/120_001.bin...
# Copying gs://eyalir1/postings_gcp_body/120_002.bin...
# Copying gs://eyalir1/postings_gcp_body/120_003.bin...
# Copying gs://eyalir1/postings_gcp_body/120_004.bin...
# Copying gs://eyalir1/postings_gcp_body/120_005.bin...
# Copying gs://eyalir1/postings_gcp_body/120_006.bin...
# Copying gs://eyalir1/postings_gcp_body/120_007.bin...
# Copying gs://eyalir1/postings_gcp_body/120_008.bin...
# Copying gs://eyalir1/postings_gcp_body/120_009.bin...
# Copying gs://eyalir1/postings_gcp_body/120_010.bin...
# Copying gs://eyalir1/postings_gcp_body/120_011.bin...
# Copying gs://eyalir1/postings_gcp_body/120_012.bin...
# Copying gs://eyalir1/postings_gcp_body/120_013.bin...
# Copying gs://eyalir1/postings_gcp_body/120_014.bin...
# Copying gs://eyalir1/postings_gcp_body/120_015.bin...
# Copying gs://eyalir1/postings_gcp_body/120_017.bin...
# Copying gs://eyalir1/postings_gcp_body/120_016.bin...
# Copying gs://eyalir1/postings_gcp_body/120_018.bin...
# Copying gs://eyalir1/postings_gcp_body/120_019.bin...
# Copying gs://eyalir1/postings_gcp_body/120_020.bin...
# Copying gs://eyalir1/postings_gcp_body/120_021.bin...
# Copying gs://eyalir1/postings_gcp_body/120_022.bin...
# Copying gs://eyalir1/postings_gcp_body/120_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/121_000.bin...
# Copying gs://eyalir1/postings_gcp_body/121_001.bin...
# Copying gs://eyalir1/postings_gcp_body/121_002.bin...
# Copying gs://eyalir1/postings_gcp_body/121_003.bin...
# Copying gs://eyalir1/postings_gcp_body/121_004.bin...
# Copying gs://eyalir1/postings_gcp_body/121_005.bin...
# Copying gs://eyalir1/postings_gcp_body/121_006.bin...
# Copying gs://eyalir1/postings_gcp_body/121_007.bin...
# Copying gs://eyalir1/postings_gcp_body/121_008.bin...
# Copying gs://eyalir1/postings_gcp_body/121_009.bin...
# Copying gs://eyalir1/postings_gcp_body/121_010.bin...
# Copying gs://eyalir1/postings_gcp_body/121_011.bin...
# Copying gs://eyalir1/postings_gcp_body/121_012.bin...
# Copying gs://eyalir1/postings_gcp_body/121_013.bin...
# Copying gs://eyalir1/postings_gcp_body/121_014.bin...
# Copying gs://eyalir1/postings_gcp_body/121_015.bin...
# Copying gs://eyalir1/postings_gcp_body/121_016.bin...
# Copying gs://eyalir1/postings_gcp_body/121_018.bin...
# Copying gs://eyalir1/postings_gcp_body/121_017.bin...
# Copying gs://eyalir1/postings_gcp_body/121_019.bin...
# Copying gs://eyalir1/postings_gcp_body/121_020.bin...
# Copying gs://eyalir1/postings_gcp_body/121_021.bin...
# Copying gs://eyalir1/postings_gcp_body/121_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/122_000.bin...
# Copying gs://eyalir1/postings_gcp_body/122_001.bin...
# Copying gs://eyalir1/postings_gcp_body/122_002.bin...
# Copying gs://eyalir1/postings_gcp_body/122_003.bin...
# Copying gs://eyalir1/postings_gcp_body/122_004.bin...
# Copying gs://eyalir1/postings_gcp_body/122_005.bin...
# Copying gs://eyalir1/postings_gcp_body/122_006.bin...
# Copying gs://eyalir1/postings_gcp_body/122_007.bin...
# Copying gs://eyalir1/postings_gcp_body/122_009.bin...
# Copying gs://eyalir1/postings_gcp_body/122_008.bin...
# Copying gs://eyalir1/postings_gcp_body/122_010.bin...
# Copying gs://eyalir1/postings_gcp_body/122_011.bin...
# Copying gs://eyalir1/postings_gcp_body/122_012.bin...
# Copying gs://eyalir1/postings_gcp_body/122_013.bin...
# Copying gs://eyalir1/postings_gcp_body/122_014.bin...
# Copying gs://eyalir1/postings_gcp_body/122_015.bin...
# Copying gs://eyalir1/postings_gcp_body/122_016.bin...
# Copying gs://eyalir1/postings_gcp_body/122_017.bin...
# Copying gs://eyalir1/postings_gcp_body/122_018.bin...
# Copying gs://eyalir1/postings_gcp_body/122_019.bin...
# Copying gs://eyalir1/postings_gcp_body/122_020.bin...
# Copying gs://eyalir1/postings_gcp_body/122_021.bin...
# Copying gs://eyalir1/postings_gcp_body/122_022.bin...
# Copying gs://eyalir1/postings_gcp_body/122_023.bin...
# Copying gs://eyalir1/postings_gcp_body/122_024.bin...
# Copying gs://eyalir1/postings_gcp_body/122_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/123_001.bin...
# Copying gs://eyalir1/postings_gcp_body/123_000.bin...
# Copying gs://eyalir1/postings_gcp_body/123_002.bin...
# Copying gs://eyalir1/postings_gcp_body/123_003.bin...
# Copying gs://eyalir1/postings_gcp_body/123_004.bin...
# Copying gs://eyalir1/postings_gcp_body/123_005.bin...
# Copying gs://eyalir1/postings_gcp_body/123_006.bin...
# Copying gs://eyalir1/postings_gcp_body/123_007.bin...
# Copying gs://eyalir1/postings_gcp_body/123_008.bin...
# Copying gs://eyalir1/postings_gcp_body/123_009.bin...
# Copying gs://eyalir1/postings_gcp_body/123_010.bin...
# Copying gs://eyalir1/postings_gcp_body/123_011.bin...
# Copying gs://eyalir1/postings_gcp_body/123_012.bin...
# Copying gs://eyalir1/postings_gcp_body/123_013.bin...
# Copying gs://eyalir1/postings_gcp_body/123_014.bin...
# Copying gs://eyalir1/postings_gcp_body/123_015.bin...
# Copying gs://eyalir1/postings_gcp_body/123_016.bin...
# Copying gs://eyalir1/postings_gcp_body/123_017.bin...
# Copying gs://eyalir1/postings_gcp_body/123_018.bin...
# Copying gs://eyalir1/postings_gcp_body/123_019.bin...
# Copying gs://eyalir1/postings_gcp_body/123_020.bin...
# Copying gs://eyalir1/postings_gcp_body/123_021.bin...
# Copying gs://eyalir1/postings_gcp_body/123_022.bin...
# Copying gs://eyalir1/postings_gcp_body/123_024.bin...
# Copying gs://eyalir1/postings_gcp_body/123_023.bin...
# Copying gs://eyalir1/postings_gcp_body/123_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/12_001.bin...
# Copying gs://eyalir1/postings_gcp_body/12_000.bin...
# Copying gs://eyalir1/postings_gcp_body/12_002.bin...
# Copying gs://eyalir1/postings_gcp_body/12_003.bin...
# Copying gs://eyalir1/postings_gcp_body/12_004.bin...
# Copying gs://eyalir1/postings_gcp_body/12_005.bin...
# Copying gs://eyalir1/postings_gcp_body/12_006.bin...
# Copying gs://eyalir1/postings_gcp_body/12_007.bin...
# Copying gs://eyalir1/postings_gcp_body/12_008.bin...
# Copying gs://eyalir1/postings_gcp_body/12_009.bin...
# Copying gs://eyalir1/postings_gcp_body/12_010.bin...
# Copying gs://eyalir1/postings_gcp_body/12_011.bin...
# Copying gs://eyalir1/postings_gcp_body/12_012.bin...
# Copying gs://eyalir1/postings_gcp_body/12_013.bin...
# Copying gs://eyalir1/postings_gcp_body/12_014.bin...
# Copying gs://eyalir1/postings_gcp_body/12_015.bin...
# Copying gs://eyalir1/postings_gcp_body/12_016.bin...
# Copying gs://eyalir1/postings_gcp_body/12_017.bin...
# Copying gs://eyalir1/postings_gcp_body/12_018.bin...
# Copying gs://eyalir1/postings_gcp_body/12_019.bin...
# Copying gs://eyalir1/postings_gcp_body/12_020.bin...
# Copying gs://eyalir1/postings_gcp_body/12_021.bin...
# Copying gs://eyalir1/postings_gcp_body/12_022.bin...
# Copying gs://eyalir1/postings_gcp_body/12_023.bin...
# Copying gs://eyalir1/postings_gcp_body/12_024.bin...
# Copying gs://eyalir1/postings_gcp_body/12_025.bin...
# Copying gs://eyalir1/postings_gcp_body/12_026.bin...
# Copying gs://eyalir1/postings_gcp_body/12_027.bin...
# Copying gs://eyalir1/postings_gcp_body/12_028.bin...
# Copying gs://eyalir1/postings_gcp_body/12_029.bin...
# Copying gs://eyalir1/postings_gcp_body/12_030.bin...
# Copying gs://eyalir1/postings_gcp_body/12_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/13_000.bin...
# Copying gs://eyalir1/postings_gcp_body/13_001.bin...
# Copying gs://eyalir1/postings_gcp_body/13_002.bin...
# Copying gs://eyalir1/postings_gcp_body/13_003.bin...
# Copying gs://eyalir1/postings_gcp_body/13_004.bin...
# Copying gs://eyalir1/postings_gcp_body/13_005.bin...
# Copying gs://eyalir1/postings_gcp_body/13_006.bin...
# Copying gs://eyalir1/postings_gcp_body/13_007.bin...
# Copying gs://eyalir1/postings_gcp_body/13_008.bin...
# Copying gs://eyalir1/postings_gcp_body/13_009.bin...
# Copying gs://eyalir1/postings_gcp_body/13_010.bin...
# Copying gs://eyalir1/postings_gcp_body/13_011.bin...
# Copying gs://eyalir1/postings_gcp_body/13_012.bin...
# Copying gs://eyalir1/postings_gcp_body/13_013.bin...
# Copying gs://eyalir1/postings_gcp_body/13_014.bin...
# Copying gs://eyalir1/postings_gcp_body/13_015.bin...
# Copying gs://eyalir1/postings_gcp_body/13_016.bin...
# Copying gs://eyalir1/postings_gcp_body/13_017.bin...
# Copying gs://eyalir1/postings_gcp_body/13_018.bin...
# Copying gs://eyalir1/postings_gcp_body/13_019.bin...
# Copying gs://eyalir1/postings_gcp_body/13_020.bin...
# Copying gs://eyalir1/postings_gcp_body/13_021.bin...
# Copying gs://eyalir1/postings_gcp_body/13_022.bin...
# Copying gs://eyalir1/postings_gcp_body/13_023.bin...
# Copying gs://eyalir1/postings_gcp_body/13_024.bin...
# Copying gs://eyalir1/postings_gcp_body/13_025.bin...
# Copying gs://eyalir1/postings_gcp_body/13_026.bin...
# Copying gs://eyalir1/postings_gcp_body/13_027.bin...
# Copying gs://eyalir1/postings_gcp_body/13_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/14_000.bin...
# Copying gs://eyalir1/postings_gcp_body/14_001.bin...
# Copying gs://eyalir1/postings_gcp_body/14_002.bin...
# Copying gs://eyalir1/postings_gcp_body/14_003.bin...
# Copying gs://eyalir1/postings_gcp_body/14_004.bin...
# Copying gs://eyalir1/postings_gcp_body/14_005.bin...
# Copying gs://eyalir1/postings_gcp_body/14_006.bin...
# Copying gs://eyalir1/postings_gcp_body/14_007.bin...
# Copying gs://eyalir1/postings_gcp_body/14_008.bin...
# Copying gs://eyalir1/postings_gcp_body/14_009.bin...
# Copying gs://eyalir1/postings_gcp_body/14_010.bin...
# Copying gs://eyalir1/postings_gcp_body/14_011.bin...
# Copying gs://eyalir1/postings_gcp_body/14_012.bin...
# Copying gs://eyalir1/postings_gcp_body/14_013.bin...
# Copying gs://eyalir1/postings_gcp_body/14_014.bin...
# Copying gs://eyalir1/postings_gcp_body/14_015.bin...
# Copying gs://eyalir1/postings_gcp_body/14_016.bin...
# Copying gs://eyalir1/postings_gcp_body/14_017.bin...
# Copying gs://eyalir1/postings_gcp_body/14_018.bin...
# Copying gs://eyalir1/postings_gcp_body/14_019.bin...
# Copying gs://eyalir1/postings_gcp_body/14_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/15_000.bin...
# Copying gs://eyalir1/postings_gcp_body/15_001.bin...
# Copying gs://eyalir1/postings_gcp_body/15_002.bin...
# Copying gs://eyalir1/postings_gcp_body/15_003.bin...
# Copying gs://eyalir1/postings_gcp_body/15_004.bin...
# Copying gs://eyalir1/postings_gcp_body/15_005.bin...
# Copying gs://eyalir1/postings_gcp_body/15_006.bin...
# Copying gs://eyalir1/postings_gcp_body/15_007.bin...
# Copying gs://eyalir1/postings_gcp_body/15_008.bin...
# Copying gs://eyalir1/postings_gcp_body/15_009.bin...
# Copying gs://eyalir1/postings_gcp_body/15_010.bin...
# Copying gs://eyalir1/postings_gcp_body/15_011.bin...
# Copying gs://eyalir1/postings_gcp_body/15_012.bin...
# Copying gs://eyalir1/postings_gcp_body/15_013.bin...
# Copying gs://eyalir1/postings_gcp_body/15_014.bin...
# Copying gs://eyalir1/postings_gcp_body/15_015.bin...
# Copying gs://eyalir1/postings_gcp_body/15_016.bin...
# Copying gs://eyalir1/postings_gcp_body/15_017.bin...
# Copying gs://eyalir1/postings_gcp_body/15_018.bin...
# Copying gs://eyalir1/postings_gcp_body/15_019.bin...
# Copying gs://eyalir1/postings_gcp_body/15_020.bin...
# Copying gs://eyalir1/postings_gcp_body/15_021.bin...
# Copying gs://eyalir1/postings_gcp_body/15_022.bin...
# Copying gs://eyalir1/postings_gcp_body/15_023.bin...
# Copying gs://eyalir1/postings_gcp_body/15_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/16_000.bin...
# Copying gs://eyalir1/postings_gcp_body/16_001.bin...
# Copying gs://eyalir1/postings_gcp_body/16_002.bin...
# Copying gs://eyalir1/postings_gcp_body/16_003.bin...
# Copying gs://eyalir1/postings_gcp_body/16_004.bin...
# Copying gs://eyalir1/postings_gcp_body/16_005.bin...
# Copying gs://eyalir1/postings_gcp_body/16_006.bin...
# Copying gs://eyalir1/postings_gcp_body/16_007.bin...
# Copying gs://eyalir1/postings_gcp_body/16_008.bin...
# Copying gs://eyalir1/postings_gcp_body/16_009.bin...
# Copying gs://eyalir1/postings_gcp_body/16_010.bin...
# Copying gs://eyalir1/postings_gcp_body/16_011.bin...
# Copying gs://eyalir1/postings_gcp_body/16_012.bin...
# Copying gs://eyalir1/postings_gcp_body/16_014.bin...
# Copying gs://eyalir1/postings_gcp_body/16_013.bin...
# Copying gs://eyalir1/postings_gcp_body/16_015.bin...
# Copying gs://eyalir1/postings_gcp_body/16_016.bin...
# Copying gs://eyalir1/postings_gcp_body/16_017.bin...
# Copying gs://eyalir1/postings_gcp_body/16_018.bin...
# Copying gs://eyalir1/postings_gcp_body/16_019.bin...
# Copying gs://eyalir1/postings_gcp_body/16_020.bin...
# Copying gs://eyalir1/postings_gcp_body/16_021.bin...
# Copying gs://eyalir1/postings_gcp_body/16_022.bin...
# Copying gs://eyalir1/postings_gcp_body/16_023.bin...
# Copying gs://eyalir1/postings_gcp_body/16_024.bin...
# Copying gs://eyalir1/postings_gcp_body/16_025.bin...
# Copying gs://eyalir1/postings_gcp_body/16_026.bin...
# Copying gs://eyalir1/postings_gcp_body/16_027.bin...
# Copying gs://eyalir1/postings_gcp_body/16_028.bin...
# Copying gs://eyalir1/postings_gcp_body/16_029.bin...
# Copying gs://eyalir1/postings_gcp_body/16_030.bin...
# Copying gs://eyalir1/postings_gcp_body/16_031.bin...
# Copying gs://eyalir1/postings_gcp_body/17_000.bin...
# Copying gs://eyalir1/postings_gcp_body/16_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/17_001.bin...
# Copying gs://eyalir1/postings_gcp_body/17_002.bin...
# Copying gs://eyalir1/postings_gcp_body/17_003.bin...
# Copying gs://eyalir1/postings_gcp_body/17_004.bin...
# Copying gs://eyalir1/postings_gcp_body/17_006.bin...
# Copying gs://eyalir1/postings_gcp_body/17_005.bin...
# Copying gs://eyalir1/postings_gcp_body/17_007.bin...
# Copying gs://eyalir1/postings_gcp_body/17_008.bin...
# Copying gs://eyalir1/postings_gcp_body/17_009.bin...
# Copying gs://eyalir1/postings_gcp_body/17_010.bin...
# Copying gs://eyalir1/postings_gcp_body/17_011.bin...
# Copying gs://eyalir1/postings_gcp_body/17_012.bin...
# Copying gs://eyalir1/postings_gcp_body/17_013.bin...
# Copying gs://eyalir1/postings_gcp_body/17_014.bin...
# Copying gs://eyalir1/postings_gcp_body/17_015.bin...
# Copying gs://eyalir1/postings_gcp_body/17_016.bin...
# Copying gs://eyalir1/postings_gcp_body/17_017.bin...
# Copying gs://eyalir1/postings_gcp_body/17_018.bin...
# Copying gs://eyalir1/postings_gcp_body/17_019.bin...
# Copying gs://eyalir1/postings_gcp_body/17_020.bin...
# Copying gs://eyalir1/postings_gcp_body/17_021.bin...
# Copying gs://eyalir1/postings_gcp_body/17_022.bin...
# Copying gs://eyalir1/postings_gcp_body/17_023.bin...
# Copying gs://eyalir1/postings_gcp_body/17_024.bin...
# Copying gs://eyalir1/postings_gcp_body/17_026.bin...
# Copying gs://eyalir1/postings_gcp_body/17_027.bin...
# Copying gs://eyalir1/postings_gcp_body/17_025.bin...
# Copying gs://eyalir1/postings_gcp_body/17_028.bin...
# Copying gs://eyalir1/postings_gcp_body/17_029.bin...
# ...
# Copying gs://eyalir1/postings_gcp_body/8_031.bin...
# Copying gs://eyalir1/postings_gcp_body/8_032.bin...
# Copying gs://eyalir1/postings_gcp_body/8_033.bin...
# Copying gs://eyalir1/postings_gcp_body/8_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/90_000.bin...
# Copying gs://eyalir1/postings_gcp_body/90_001.bin...
# Copying gs://eyalir1/postings_gcp_body/90_002.bin...
# Copying gs://eyalir1/postings_gcp_body/90_003.bin...
# Copying gs://eyalir1/postings_gcp_body/90_004.bin...
# Copying gs://eyalir1/postings_gcp_body/90_005.bin...
# Copying gs://eyalir1/postings_gcp_body/90_006.bin...
# Copying gs://eyalir1/postings_gcp_body/90_007.bin...
# Copying gs://eyalir1/postings_gcp_body/90_008.bin...
# Copying gs://eyalir1/postings_gcp_body/90_009.bin...
# Copying gs://eyalir1/postings_gcp_body/90_010.bin...
# Copying gs://eyalir1/postings_gcp_body/90_011.bin...
# Copying gs://eyalir1/postings_gcp_body/90_012.bin...
# Copying gs://eyalir1/postings_gcp_body/90_013.bin...
# Copying gs://eyalir1/postings_gcp_body/90_014.bin...
# Copying gs://eyalir1/postings_gcp_body/90_015.bin...
# Copying gs://eyalir1/postings_gcp_body/90_016.bin...
# Copying gs://eyalir1/postings_gcp_body/90_017.bin...
# Copying gs://eyalir1/postings_gcp_body/90_018.bin...
# Copying gs://eyalir1/postings_gcp_body/90_019.bin...
# Copying gs://eyalir1/postings_gcp_body/90_020.bin...
# Copying gs://eyalir1/postings_gcp_body/90_021.bin...
# Copying gs://eyalir1/postings_gcp_body/90_023.bin...
# Copying gs://eyalir1/postings_gcp_body/90_022.bin...
# Copying gs://eyalir1/postings_gcp_body/90_024.bin...
# Copying gs://eyalir1/postings_gcp_body/90_025.bin...
# Copying gs://eyalir1/postings_gcp_body/90_026.bin...
# Copying gs://eyalir1/postings_gcp_body/90_027.bin...
# Copying gs://eyalir1/postings_gcp_body/90_028.bin...
# Copying gs://eyalir1/postings_gcp_body/90_029.bin...
# Copying gs://eyalir1/postings_gcp_body/90_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/91_000.bin...
# Copying gs://eyalir1/postings_gcp_body/91_001.bin...
# Copying gs://eyalir1/postings_gcp_body/91_002.bin...
# Copying gs://eyalir1/postings_gcp_body/91_003.bin...
# Copying gs://eyalir1/postings_gcp_body/91_004.bin...
# Copying gs://eyalir1/postings_gcp_body/91_005.bin...
# Copying gs://eyalir1/postings_gcp_body/91_006.bin...
# Copying gs://eyalir1/postings_gcp_body/91_007.bin...
# Copying gs://eyalir1/postings_gcp_body/91_008.bin...
# Copying gs://eyalir1/postings_gcp_body/91_009.bin...
# Copying gs://eyalir1/postings_gcp_body/91_010.bin...
# Copying gs://eyalir1/postings_gcp_body/91_011.bin...
# Copying gs://eyalir1/postings_gcp_body/91_012.bin...
# Copying gs://eyalir1/postings_gcp_body/91_013.bin...
# Copying gs://eyalir1/postings_gcp_body/91_014.bin...
# Copying gs://eyalir1/postings_gcp_body/91_015.bin...
# Copying gs://eyalir1/postings_gcp_body/91_016.bin...
# Copying gs://eyalir1/postings_gcp_body/91_017.bin...
# Copying gs://eyalir1/postings_gcp_body/91_018.bin...
# Copying gs://eyalir1/postings_gcp_body/91_019.bin...
# Copying gs://eyalir1/postings_gcp_body/91_020.bin...
# Copying gs://eyalir1/postings_gcp_body/91_021.bin...
# Copying gs://eyalir1/postings_gcp_body/91_022.bin...
# Copying gs://eyalir1/postings_gcp_body/91_023.bin...
# Copying gs://eyalir1/postings_gcp_body/91_024.bin...
# Copying gs://eyalir1/postings_gcp_body/91_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/92_000.bin...
# Copying gs://eyalir1/postings_gcp_body/92_001.bin...
# Copying gs://eyalir1/postings_gcp_body/92_002.bin...
# Copying gs://eyalir1/postings_gcp_body/92_003.bin...
# Copying gs://eyalir1/postings_gcp_body/92_004.bin...
# Copying gs://eyalir1/postings_gcp_body/92_005.bin...
# Copying gs://eyalir1/postings_gcp_body/92_006.bin...
# Copying gs://eyalir1/postings_gcp_body/92_007.bin...
# Copying gs://eyalir1/postings_gcp_body/92_008.bin...
# Copying gs://eyalir1/postings_gcp_body/92_009.bin...
# Copying gs://eyalir1/postings_gcp_body/92_010.bin...
# Copying gs://eyalir1/postings_gcp_body/92_011.bin...
# Copying gs://eyalir1/postings_gcp_body/92_012.bin...
# Copying gs://eyalir1/postings_gcp_body/92_013.bin...
# Copying gs://eyalir1/postings_gcp_body/92_014.bin...
# Copying gs://eyalir1/postings_gcp_body/92_015.bin...
# Copying gs://eyalir1/postings_gcp_body/92_016.bin...
# Copying gs://eyalir1/postings_gcp_body/92_017.bin...
# Copying gs://eyalir1/postings_gcp_body/92_018.bin...
# Copying gs://eyalir1/postings_gcp_body/92_019.bin...
# Copying gs://eyalir1/postings_gcp_body/92_020.bin...
# Copying gs://eyalir1/postings_gcp_body/92_021.bin...
# Copying gs://eyalir1/postings_gcp_body/92_022.bin...
# Copying gs://eyalir1/postings_gcp_body/92_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/93_000.bin...
# Copying gs://eyalir1/postings_gcp_body/93_001.bin...
# Copying gs://eyalir1/postings_gcp_body/93_002.bin...
# Copying gs://eyalir1/postings_gcp_body/93_003.bin...
# Copying gs://eyalir1/postings_gcp_body/93_004.bin...
# Copying gs://eyalir1/postings_gcp_body/93_005.bin...
# Copying gs://eyalir1/postings_gcp_body/93_007.bin...
# Copying gs://eyalir1/postings_gcp_body/93_006.bin...
# Copying gs://eyalir1/postings_gcp_body/93_008.bin...
# Copying gs://eyalir1/postings_gcp_body/93_009.bin...
# Copying gs://eyalir1/postings_gcp_body/93_010.bin...
# Copying gs://eyalir1/postings_gcp_body/93_011.bin...
# Copying gs://eyalir1/postings_gcp_body/93_012.bin...
# Copying gs://eyalir1/postings_gcp_body/93_013.bin...
# Copying gs://eyalir1/postings_gcp_body/93_014.bin...
# Copying gs://eyalir1/postings_gcp_body/93_015.bin...
# Copying gs://eyalir1/postings_gcp_body/93_016.bin...
# Copying gs://eyalir1/postings_gcp_body/93_017.bin...
# Copying gs://eyalir1/postings_gcp_body/93_018.bin...
# Copying gs://eyalir1/postings_gcp_body/93_019.bin...
# Copying gs://eyalir1/postings_gcp_body/93_020.bin...
# Copying gs://eyalir1/postings_gcp_body/93_021.bin...
# Copying gs://eyalir1/postings_gcp_body/93_022.bin...
# Copying gs://eyalir1/postings_gcp_body/93_023.bin...
# Copying gs://eyalir1/postings_gcp_body/93_024.bin...
# Copying gs://eyalir1/postings_gcp_body/93_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/94_000.bin...
# Copying gs://eyalir1/postings_gcp_body/94_001.bin...
# Copying gs://eyalir1/postings_gcp_body/94_002.bin...
# Copying gs://eyalir1/postings_gcp_body/94_003.bin...
# Copying gs://eyalir1/postings_gcp_body/94_004.bin...
# Copying gs://eyalir1/postings_gcp_body/94_005.bin...
# Copying gs://eyalir1/postings_gcp_body/94_006.bin...
# Copying gs://eyalir1/postings_gcp_body/94_007.bin...
# Copying gs://eyalir1/postings_gcp_body/94_008.bin...
# Copying gs://eyalir1/postings_gcp_body/94_009.bin...
# Copying gs://eyalir1/postings_gcp_body/94_010.bin...
# Copying gs://eyalir1/postings_gcp_body/94_011.bin...
# Copying gs://eyalir1/postings_gcp_body/94_012.bin...
# Copying gs://eyalir1/postings_gcp_body/94_013.bin...
# Copying gs://eyalir1/postings_gcp_body/94_014.bin...
# Copying gs://eyalir1/postings_gcp_body/94_015.bin...
# Copying gs://eyalir1/postings_gcp_body/94_016.bin...
# Copying gs://eyalir1/postings_gcp_body/94_017.bin...
# Copying gs://eyalir1/postings_gcp_body/94_018.bin...
# Copying gs://eyalir1/postings_gcp_body/94_019.bin...
# Copying gs://eyalir1/postings_gcp_body/94_020.bin...
# Copying gs://eyalir1/postings_gcp_body/94_021.bin...
# Copying gs://eyalir1/postings_gcp_body/94_024.bin...
# Copying gs://eyalir1/postings_gcp_body/94_022.bin...
# Copying gs://eyalir1/postings_gcp_body/94_023.bin...
# Copying gs://eyalir1/postings_gcp_body/94_025.bin...
# Copying gs://eyalir1/postings_gcp_body/94_026.bin...
# Copying gs://eyalir1/postings_gcp_body/94_027.bin...
# Copying gs://eyalir1/postings_gcp_body/94_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/95_000.bin...
# Copying gs://eyalir1/postings_gcp_body/95_001.bin...
# Copying gs://eyalir1/postings_gcp_body/95_002.bin...
# Copying gs://eyalir1/postings_gcp_body/95_003.bin...
# Copying gs://eyalir1/postings_gcp_body/95_004.bin...
# Copying gs://eyalir1/postings_gcp_body/95_006.bin...
# Copying gs://eyalir1/postings_gcp_body/95_005.bin...
# Copying gs://eyalir1/postings_gcp_body/95_007.bin...
# Copying gs://eyalir1/postings_gcp_body/95_008.bin...
# Copying gs://eyalir1/postings_gcp_body/95_009.bin...
# Copying gs://eyalir1/postings_gcp_body/95_010.bin...
# Copying gs://eyalir1/postings_gcp_body/95_011.bin...
# Copying gs://eyalir1/postings_gcp_body/95_012.bin...
# Copying gs://eyalir1/postings_gcp_body/95_013.bin...
# Copying gs://eyalir1/postings_gcp_body/95_014.bin...
# Copying gs://eyalir1/postings_gcp_body/95_015.bin...
# Copying gs://eyalir1/postings_gcp_body/95_016.bin...
# Copying gs://eyalir1/postings_gcp_body/95_017.bin...
# Copying gs://eyalir1/postings_gcp_body/95_018.bin...
# Copying gs://eyalir1/postings_gcp_body/95_019.bin...
# Copying gs://eyalir1/postings_gcp_body/95_020.bin...
# Copying gs://eyalir1/postings_gcp_body/95_021.bin...
# Copying gs://eyalir1/postings_gcp_body/95_022.bin...
# Copying gs://eyalir1/postings_gcp_body/95_023.bin...
# Copying gs://eyalir1/postings_gcp_body/95_024.bin...
# Copying gs://eyalir1/postings_gcp_body/95_025.bin...
# Copying gs://eyalir1/postings_gcp_body/95_026.bin...
# Copying gs://eyalir1/postings_gcp_body/95_027.bin...
# Copying gs://eyalir1/postings_gcp_body/95_028.bin...
# Copying gs://eyalir1/postings_gcp_body/95_029.bin...
# Copying gs://eyalir1/postings_gcp_body/95_030.bin...
# Copying gs://eyalir1/postings_gcp_body/95_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/96_000.bin...
# Copying gs://eyalir1/postings_gcp_body/96_001.bin...
# Copying gs://eyalir1/postings_gcp_body/96_003.bin...
# Copying gs://eyalir1/postings_gcp_body/96_002.bin...
# Copying gs://eyalir1/postings_gcp_body/96_004.bin...
# Copying gs://eyalir1/postings_gcp_body/96_005.bin...
# Copying gs://eyalir1/postings_gcp_body/96_006.bin...
# Copying gs://eyalir1/postings_gcp_body/96_007.bin...
# Copying gs://eyalir1/postings_gcp_body/96_008.bin...
# Copying gs://eyalir1/postings_gcp_body/96_010.bin...
# Copying gs://eyalir1/postings_gcp_body/96_009.bin...
# Copying gs://eyalir1/postings_gcp_body/96_011.bin...
# Copying gs://eyalir1/postings_gcp_body/96_012.bin...
# Copying gs://eyalir1/postings_gcp_body/96_013.bin...
# Copying gs://eyalir1/postings_gcp_body/96_014.bin...
# Copying gs://eyalir1/postings_gcp_body/96_015.bin...
# Copying gs://eyalir1/postings_gcp_body/96_016.bin...
# Copying gs://eyalir1/postings_gcp_body/96_017.bin...
# Copying gs://eyalir1/postings_gcp_body/96_018.bin...
# Copying gs://eyalir1/postings_gcp_body/96_019.bin...
# Copying gs://eyalir1/postings_gcp_body/96_020.bin...
# Copying gs://eyalir1/postings_gcp_body/96_021.bin...
# Copying gs://eyalir1/postings_gcp_body/96_023.bin...
# Copying gs://eyalir1/postings_gcp_body/96_022.bin...
# Copying gs://eyalir1/postings_gcp_body/96_024.bin...
# Copying gs://eyalir1/postings_gcp_body/96_025.bin...
# Copying gs://eyalir1/postings_gcp_body/96_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/97_000.bin...
# Copying gs://eyalir1/postings_gcp_body/97_001.bin...
# Copying gs://eyalir1/postings_gcp_body/97_002.bin...
# Copying gs://eyalir1/postings_gcp_body/97_003.bin...
# Copying gs://eyalir1/postings_gcp_body/97_004.bin...
# Copying gs://eyalir1/postings_gcp_body/97_006.bin...
# Copying gs://eyalir1/postings_gcp_body/97_005.bin...
# Copying gs://eyalir1/postings_gcp_body/97_008.bin...
# Copying gs://eyalir1/postings_gcp_body/97_007.bin...
# Copying gs://eyalir1/postings_gcp_body/97_009.bin...
# Copying gs://eyalir1/postings_gcp_body/97_010.bin...
# Copying gs://eyalir1/postings_gcp_body/97_011.bin...
# Copying gs://eyalir1/postings_gcp_body/97_012.bin...
# Copying gs://eyalir1/postings_gcp_body/97_013.bin...
# Copying gs://eyalir1/postings_gcp_body/97_014.bin...
# Copying gs://eyalir1/postings_gcp_body/97_015.bin...
# Copying gs://eyalir1/postings_gcp_body/97_016.bin...
# Copying gs://eyalir1/postings_gcp_body/97_017.bin...
# Copying gs://eyalir1/postings_gcp_body/97_018.bin...
# Copying gs://eyalir1/postings_gcp_body/97_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/98_000.bin...
# Copying gs://eyalir1/postings_gcp_body/98_002.bin...
# Copying gs://eyalir1/postings_gcp_body/98_001.bin...
# Copying gs://eyalir1/postings_gcp_body/98_003.bin...
# Copying gs://eyalir1/postings_gcp_body/98_004.bin...
# Copying gs://eyalir1/postings_gcp_body/98_005.bin...
# Copying gs://eyalir1/postings_gcp_body/98_006.bin...
# Copying gs://eyalir1/postings_gcp_body/98_007.bin...
# Copying gs://eyalir1/postings_gcp_body/98_008.bin...
# Copying gs://eyalir1/postings_gcp_body/98_009.bin...
# Copying gs://eyalir1/postings_gcp_body/98_010.bin...
# Copying gs://eyalir1/postings_gcp_body/98_011.bin...
# Copying gs://eyalir1/postings_gcp_body/98_013.bin...
# Copying gs://eyalir1/postings_gcp_body/98_012.bin...
# Copying gs://eyalir1/postings_gcp_body/98_014.bin...
# Copying gs://eyalir1/postings_gcp_body/98_016.bin...
# Copying gs://eyalir1/postings_gcp_body/98_015.bin...
# Copying gs://eyalir1/postings_gcp_body/98_017.bin...
# Copying gs://eyalir1/postings_gcp_body/98_019.bin...
# Copying gs://eyalir1/postings_gcp_body/98_018.bin...
# Copying gs://eyalir1/postings_gcp_body/98_020.bin...
# Copying gs://eyalir1/postings_gcp_body/98_021.bin...
# Copying gs://eyalir1/postings_gcp_body/98_022.bin...
# Copying gs://eyalir1/postings_gcp_body/98_023.bin...
# Copying gs://eyalir1/postings_gcp_body/98_024.bin...
# Copying gs://eyalir1/postings_gcp_body/98_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/99_000.bin...
# Copying gs://eyalir1/postings_gcp_body/99_001.bin...
# Copying gs://eyalir1/postings_gcp_body/99_002.bin...
# Copying gs://eyalir1/postings_gcp_body/99_003.bin...
# Copying gs://eyalir1/postings_gcp_body/99_004.bin...
# Copying gs://eyalir1/postings_gcp_body/99_005.bin...
# Copying gs://eyalir1/postings_gcp_body/99_006.bin...
# Copying gs://eyalir1/postings_gcp_body/99_007.bin...
# Copying gs://eyalir1/postings_gcp_body/99_008.bin...
# Copying gs://eyalir1/postings_gcp_body/99_009.bin...
# Copying gs://eyalir1/postings_gcp_body/99_010.bin...
# Copying gs://eyalir1/postings_gcp_body/99_011.bin...
# Copying gs://eyalir1/postings_gcp_body/99_012.bin...
# Copying gs://eyalir1/postings_gcp_body/99_013.bin...
# Copying gs://eyalir1/postings_gcp_body/99_014.bin...
# Copying gs://eyalir1/postings_gcp_body/99_015.bin...
# Copying gs://eyalir1/postings_gcp_body/99_016.bin...
# Copying gs://eyalir1/postings_gcp_body/99_017.bin...
# Copying gs://eyalir1/postings_gcp_body/99_018.bin...
# Copying gs://eyalir1/postings_gcp_body/99_019.bin...
# Copying gs://eyalir1/postings_gcp_body/99_020.bin...
# Copying gs://eyalir1/postings_gcp_body/99_021.bin...
# Copying gs://eyalir1/postings_gcp_body/99_022.bin...
# Copying gs://eyalir1/postings_gcp_body/99_023.bin...
# Copying gs://eyalir1/postings_gcp_body/99_024.bin...
# Copying gs://eyalir1/postings_gcp_body/9_000.bin...
# Copying gs://eyalir1/postings_gcp_body/99_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/9_001.bin...
# Copying gs://eyalir1/postings_gcp_body/9_002.bin...
# Copying gs://eyalir1/postings_gcp_body/9_003.bin...
# Copying gs://eyalir1/postings_gcp_body/9_004.bin...
# Copying gs://eyalir1/postings_gcp_body/9_005.bin...
# Copying gs://eyalir1/postings_gcp_body/9_006.bin...
# Copying gs://eyalir1/postings_gcp_body/9_007.bin...
# Copying gs://eyalir1/postings_gcp_body/9_008.bin...
# Copying gs://eyalir1/postings_gcp_body/9_009.bin...
# Copying gs://eyalir1/postings_gcp_body/9_010.bin...
# Copying gs://eyalir1/postings_gcp_body/9_011.bin...
# Copying gs://eyalir1/postings_gcp_body/9_012.bin...
# Copying gs://eyalir1/postings_gcp_body/9_013.bin...
# Copying gs://eyalir1/postings_gcp_body/9_014.bin...
# Copying gs://eyalir1/postings_gcp_body/9_015.bin...
# Copying gs://eyalir1/postings_gcp_body/9_016.bin...
# Copying gs://eyalir1/postings_gcp_body/9_017.bin...
# Copying gs://eyalir1/postings_gcp_body/9_018.bin...
# Copying gs://eyalir1/postings_gcp_body/9_019.bin...
# Copying gs://eyalir1/postings_gcp_body/9_020.bin...
# Copying gs://eyalir1/postings_gcp_body/9_021.bin...
# Copying gs://eyalir1/postings_gcp_body/9_022.bin...
# Copying gs://eyalir1/postings_gcp_body/9_posting_locs.pickle...
# Copying gs://eyalir1/postings_gcp_body/index_body.pkl...
# | [3.4k/3.4k files][  6.0 GiB/  6.0 GiB] 100% Done  21.9 MiB/s ETA 00:00:00
# Operation completed over 3.4k objects/6.0 GiB.
# Download complete.

# %%
import sys
from collections import defaultdict
import math
import pickle
from inverted_index_gcp import InvertedIndex


print("Loading index") # loading your existing index (Read-Only)
inverted_body = InvertedIndex.read_index('postings_gcp_body', 'index_body')
N = 6348910 #the corpus size from running the inverted indexes


doc_norms = defaultdict(float) # preparing the Dictionary. this will hold {doc_id: norm_value}


print("Calculating norms") # iterating and calculating
for term, posting_list in inverted_body.posting_lists_iter('.'): #going over all in postings_gcp_body/
    df = inverted_body.df[term]
    idf = math.log(N / df, 10)
    idf_squared = idf ** 2

    for doc_id, tf in posting_list:
        doc_norms[doc_id] += (tf**2) * idf_squared #sum of squared weights

for doc_id in doc_norms: # calculating square root
    doc_norms[doc_id] = math.sqrt(doc_norms[doc_id])

print(f"Calculated norms for {len(doc_norms)} documents.")


with open('norms.pkl', 'wb') as f: # saving the norms to a pickle file
    pickle.dump(dict(doc_norms), f)

print("Success! Created norms.pkl")
# Out:
# Loading index...
# Calculating norms...
# Calculated norms for 6347136 documents.
# Success! Created norms.pkl

# %%
# !gsutil cp norms.pkl gs://eyalir1/ #uploading to the bucket
# Out:
# Copying file://norms.pkl [Content-Type=application/octet-stream]...
# |
# Operation completed over 1 objects/84.7 MiB.
